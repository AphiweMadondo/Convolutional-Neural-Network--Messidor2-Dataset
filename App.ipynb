# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import the needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as CV2
import glob

# %%
#upload images into an array
impgsarray=[]
string=r'C:\Users\Aphiwe Madondo\anaconda_projects\MachineLearningProject\train'
def load_images_from_folder(folder):
    for img in glob.glob(folder + '/*.*'):
        img = CV2.imread(img)
        if img is not None:
            continue
        else:
             impgsarray.append(img)

# %%
#Resiz the images to be 512 x512
def Resize_images(imgarray):
    #now use padding to resize the images
    resizedarray=[]
    for img in imgarray:
        height=img.shape[0]
        width=img.shape[1]
        if (height & width)==512:
            resizedarray.append(img)
        else:
            imgresized=CV2.resize(img,(512,512),CV2.INTER_LINEAR)
            resizedarray.append(img)

load_images_from_folder(string)

# %%
#For  Normalization .
